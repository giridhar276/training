# %%
name = "python"
id(name)

# %%
alist = [10,20,30]
id(alist)
# Out:
# 1377452164032

# %%
alist = [10,20,50]
id(alist)
# Out:
# 2751362316160

# %%
val = 10
id(val)
# Out:
# 140724003138264

# %%
max(alist)
# Out:
# 50

# %%
min(alist)
# Out:
# 10

# %%
sum(alist)
# Out:
# 80

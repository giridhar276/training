# %%
import pandas as pd

# %%
df = pd.read_csv("empinfo.csv")

# %%
type(df)

# %%
# display first 5 rows
df.head(8)

# %%
# display last 10 rows
df.tail(10)

# %%
# display from 10 to 20th record
#df.iloc[rows, columns]
df.iloc[10:21]

# %%
df.iloc[10:21,2:5]

# %%
# redirecting the output to the file
df.head(10).to_csv("first10records.csv")

# %%
df.iloc[10:21,2:5].to_csv("indexvalues.csv")

# %%
# display datatype of each column
df.info()

# %%
# display datatypes
df.dtypes

# %%
# summary of dataframe
df.describe()

# %%
# display single column
df['workclass']

# %%
# display multiple columns
df[['workclass','education']]

# %%
# display all unique workclasses
df['workclass'].unique()

# %%
# display the count of unique workclasses
df['workclass'].nunique()

# %%
df['workclass'].value_counts()

# %%
# sorting by age
df.sort_values('age')

# %%
df.sort_values('age', ascending=False)

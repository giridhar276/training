# %% [markdown]
# ## 1. Load the dataset and display the first 5 rows.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('software_companies_dataset_v2.csv')
df['Incorporation_Date'] = pd.to_datetime(df['Incorporation_Date'])
df['Last_Funding_Date'] = pd.to_datetime(df['Last_Funding_Date'])
df.head()
# Out:
#    Company_ID        Company_Name        Industry Headquarters_City  \
# 0      807869        Neo Soft 760      HealthTech              Pune
# 1      985270  Next Analytics 229          Gaming             Noida
# 2      615066    Innova Works 693   Cybersecurity           Chennai
# 3      756196     Secure Labs 605   Cybersecurity             Noida
# 4      292453    Logic Systems 31  Cloud Services               NaN
#
#      Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 0  Australia        Private              SME         Azure      Medium
# 1        UAE        Startup            B2B2C           GCP         Low
# 2    Germany        Startup              B2B     IBM Cloud      Medium
# 3         UK         Public              SME           GCP         Low
# 4        UAE        Private            B2B2C           AWS      Medium
#
#    Year_Founded  ... Market_Share Product_Lines  R&D_Spending  Average_Salary  \
# ...

# %% [markdown]
# ## 2. Display the last 5 rows of the dataset.

# %%
df.tail()
# Out:
#      Company_ID        Company_Name             Industry Headquarters_City  \
# 995      647311     Innova Corp 325  Enterprise Software         Bengaluru
# 996      542547     Vertex Works 94  Enterprise Software          Gurugram
# 997      621949  Tech Platforms 456       Cloud Services           Kolkata
# 998      798956     Vertex Tech 105           E-commerce         Ahmedabad
# 999      725149     Innova Labs 192                AI/ML           Kolkata
#
#     Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 995     UAE        Private              B2B           AWS        High
# 996     UAE         Public              B2C           NaN        High
# 997  Canada     Subsidiary              B2C   Multi-Cloud      Medium
# 998   India        Private              B2B     IBM Cloud   Very High
# 999     UAE         Public       Enterprise         Azure         Low
#
#      Year_Founded  ... Market_Share Product_Lines  R&D_Spending  \
# ...

# %% [markdown]
# ## 3. Check the shape of the dataset.

# %%
df.shape
# Out:
# (1000, 25)

# %% [markdown]
# ## 4. Display the column names.

# %%
df.columns.tolist()
# Out:
# ['Company_ID',
#  'Company_Name',
#  'Industry',
#  'Headquarters_City',
#  'Country',
#  'Ownership_Type',
#  'Customer_Segment',
#  'Primary_Cloud',
#  'Risk_Rating',
#  'Year_Founded',
#  'Incorporation_Date',
#  'Last_Funding_Date',
#  'Employees',
#  'Annual_Revenue',
#  'Profit_Margin',
#  'Market_Share',
#  'Product_Lines',
#  'R&D_Spending',
#  'Average_Salary',
#  'Training_Hours_Per_Employee',
#  'Employee_Satisfaction',
#  'Adoption_Rate_AI',
#  'Adoption_Rate_Cloud',
#  'Adoption_Rate_Blockchain',
#  'CEO_Tenure_Years']

# %% [markdown]
# ## 5. Check the data types of all columns.

# %%
df.dtypes
# Out:
# Company_ID                              int64
# Company_Name                           object
# Industry                               object
# Headquarters_City                      object
# Country                                object
# Ownership_Type                         object
# Customer_Segment                       object
# Primary_Cloud                          object
# Risk_Rating                            object
# Year_Founded                            int64
# Incorporation_Date             datetime64[ns]
# Last_Funding_Date              datetime64[ns]
# Employees                             float64
# Annual_Revenue                        float64
# Profit_Margin                         float64
# Market_Share                          float64
# Product_Lines                           int64
# R&D_Spending                          float64
# Average_Salary                        float64
# Training_Hours_Per_Employee           float64
# ...

# %% [markdown]
# ## 6. Generate summary statistics for numerical columns.

# %%
df.describe()
# Out:
#           Company_ID  Year_Founded          Incorporation_Date  \
# count    1000.000000   1000.000000                        1000
# mean   552280.147000   2004.991000  2005-06-29 01:17:45.600000
# min    100197.000000   1985.000000         1985-01-11 00:00:00
# 25%    323385.750000   1995.000000         1995-02-24 18:00:00
# 50%    556021.000000   2006.000000         2006-08-20 12:00:00
# 75%    778638.750000   2015.250000         2015-12-26 12:00:00
# max    999887.000000   2024.000000         2024-11-23 00:00:00
# std    259554.711145     11.780055                         NaN
#
#                    Last_Funding_Date     Employees  Annual_Revenue  \
# count                            982    982.000000    9.820000e+02
# mean   2016-02-14 18:46:11.486761728  25512.567210    1.293166e+08
# min              1990-01-05 00:00:00    110.000000    5.985007e+06
# 25%              2010-12-02 12:00:00  13132.500000    5.202599e+07
# ...

# %% [markdown]
# ## 7. Generate summary statistics for categorical columns.

# %%
df.describe(include='object')
# Out:
#         Company_Name Industry Headquarters_City Country Ownership_Type  \
# count           1000      982               982    1000           1000
# unique          1000       10                10       8              4
# top     Neo Soft 760     SaaS           Chennai  Canada        Private
# freq               1      114               117     132            348
#
#        Customer_Segment Primary_Cloud Risk_Rating
# count              1000           982        1000
# unique                5             5           4
# top                 B2B           GCP      Medium
# freq                223           221         443

# %% [markdown]
# ## 8. Check the total number of missing values in each column.

# %%
df.isnull().sum()
# Out:
# Company_ID                      0
# Company_Name                    0
# Industry                       18
# Headquarters_City              18
# Country                         0
# Ownership_Type                  0
# Customer_Segment                0
# Primary_Cloud                  18
# Risk_Rating                     0
# Year_Founded                    0
# Incorporation_Date              0
# Last_Funding_Date              18
# Employees                      18
# Annual_Revenue                 18
# Profit_Margin                  18
# Market_Share                    0
# Product_Lines                   0
# R&D_Spending                    0
# Average_Salary                  0
# Training_Hours_Per_Employee     0
# Employee_Satisfaction          18
# Adoption_Rate_AI                0
# Adoption_Rate_Cloud             0
# Adoption_Rate_Blockchain        0
# CEO_Tenure_Years                0
# dtype: int64

# %% [markdown]
# ## 9. Count the total missing values in the entire dataset.

# %%
df.isnull().sum().sum()
# Out:
# np.int64(144)

# %% [markdown]
# ## 10. Display a random sample of 10 rows.

# %%
df.sample(10, random_state=42)
# Out:
#      Company_ID          Company_Name        Industry Headquarters_City  \
# 521      591967       Prime Systems 8  Cloud Services         Ahmedabad
# 737      815234   Vertex Infotech 576      E-commerce              Pune
# 740      326462  Fusion Analytics 145  Cloud Services             Noida
# 660      382978        Quantum AI 709          Gaming              Pune
# 411      819145  Vertex Analytics 652      E-commerce             Delhi
# 678      328068    Bright Systems 620             NaN           Kolkata
# 626      603312     Neo Platforms 244         FinTech           Chennai
# 513      596509       Zen Systems 691  Cloud Services           Kolkata
# 859      215476   Bright Services 154            SaaS             Delhi
# 136      221288     Logic Services 10      E-commerce         Ahmedabad
#
#        Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 521         UK        Private       Enterprise           GCP      Medium
# ...

# %% [markdown]
# ## 11. Select only the columns Company_Name, Industry, and Annual_Revenue.

# %%
df[['Company_Name', 'Industry', 'Annual_Revenue']].head()
# Out:
#          Company_Name        Industry  Annual_Revenue
# 0        Neo Soft 760      HealthTech    7.299762e+07
# 1  Next Analytics 229          Gaming    5.997070e+07
# 2    Innova Works 693   Cybersecurity    1.146540e+08
# 3     Secure Labs 605   Cybersecurity    4.802480e+07
# 4    Logic Systems 31  Cloud Services    1.851525e+08

# %% [markdown]
# ## 12. Display only rows where Industry is FinTech.

# %%
df[df['Industry'] == 'FinTech'].head()
# Out:
#     Company_ID         Company_Name Industry Headquarters_City    Country  \
# 39      570981      Bright Corp 371  FinTech         Bengaluru  Singapore
# 54      990613   Pixel Dynamics 157  FinTech         Ahmedabad         UK
# 55      106443  Vertex Networks 553  FinTech             Noida  Australia
# 57      223024          Alpha AI 20  FinTech              Pune  Australia
# 86      968146   Cyber Services 460  FinTech          Gurugram  Singapore
#
#    Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  Year_Founded  \
# 39        Startup            B2B2C     IBM Cloud   Very High          1998
# 54         Public              SME   Multi-Cloud        High          1990
# 55     Subsidiary       Enterprise   Multi-Cloud        High          1988
# 57        Startup              B2C         Azure      Medium          2002
# 86     Subsidiary            B2B2C           AWS         Low          2001
#
#     ... Market_Share Product_Lines  R&D_Spending  Average_Salary  \
# ...

# %% [markdown]
# ## 13. Display only rows where Employees are greater than 10000.

# %%
df[df['Employees'] > 10000].head()
# Out:
#    Company_ID       Company_Name             Industry Headquarters_City  \
# 0      807869       Neo Soft 760           HealthTech              Pune
# 3      756196    Secure Labs 605        Cybersecurity             Noida
# 4      292453   Logic Systems 31       Cloud Services               NaN
# 5      556753  Data Dynamics 239  Enterprise Software             Delhi
# 6      146801     Pixel Soft 575       Cloud Services             Noida
#
#      Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 0  Australia        Private              SME         Azure      Medium
# 3         UK         Public              SME           GCP         Low
# 4        UAE        Private            B2B2C           AWS      Medium
# 5  Australia        Startup            B2B2C           GCP      Medium
# 6      India        Startup              B2C     IBM Cloud      Medium
#
#    Year_Founded  ... Market_Share Product_Lines  R&D_Spending  Average_Salary  \
# ...

# %% [markdown]
# ## 14. Display companies founded after 2015.

# %%
df[df['Year_Founded'] > 2015].head()
# Out:
#     Company_ID        Company_Name             Industry Headquarters_City  \
# 0       807869        Neo Soft 760           HealthTech              Pune
# 5       556753   Data Dynamics 239  Enterprise Software             Delhi
# 11      531830  Next Solutions 221               EdTech            Mumbai
# 12      293852      Alpha Works 95  Enterprise Software           Chennai
# 19      799872       Cyber Labs 47                 SaaS         Hyderabad
#
#       Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 0   Australia        Private              SME         Azure      Medium
# 5   Australia        Startup            B2B2C           GCP      Medium
# 11    Germany     Subsidiary              SME           GCP         Low
# 12  Australia        Private              SME   Multi-Cloud        High
# 19      India        Private              SME           GCP      Medium
#
#     Year_Founded  ... Market_Share Product_Lines  R&D_Spending  \
# ...

# %% [markdown]
# ## 15. Display companies with Profit_Margin above 25.

# %%
df[df['Profit_Margin'] > 25].head()
# Out:
#     Company_ID             Company_Name             Industry  \
# 3       756196          Secure Labs 605        Cybersecurity
# 4       292453         Logic Systems 31       Cloud Services
# 7       434129       Cyber Services 430                  NaN
# 8       924528           Blue Stack 604       Cloud Services
# 10      712043  Quantum Innovations 349  Enterprise Software
#
#    Headquarters_City    Country Ownership_Type Customer_Segment Primary_Cloud  \
# 3              Noida         UK         Public              SME           GCP
# 4                NaN        UAE        Private            B2B2C           AWS
# 7          Hyderabad         UK        Private              SME   Multi-Cloud
# 8            Kolkata  Australia         Public            B2B2C           GCP
# 10             Delhi  Australia        Startup            B2B2C         Azure
#
#    Risk_Rating  Year_Founded  ... Market_Share Product_Lines  R&D_Spending  \
# ...

# %% [markdown]
# ## 16. Display companies from India or USA.

# %%
df[df['Country'].isin(['India', 'USA'])].head()
# Out:
#     Company_ID     Company_Name             Industry Headquarters_City  \
# 6       146801   Pixel Soft 575       Cloud Services             Noida
# 13      893599  Prime Works 368               Gaming         Ahmedabad
# 14      114360  Vertex Tech 827  Enterprise Software          Gurugram
# 16      226269      Neo Corp 81                  NaN            Mumbai
# 19      799872    Cyber Labs 47                 SaaS         Hyderabad
#
#    Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 6    India        Startup              B2C     IBM Cloud      Medium
# 13   India         Public              B2C     IBM Cloud        High
# 14     USA         Public              SME           GCP      Medium
# 16   India        Startup       Enterprise         Azure        High
# 19   India        Private              SME           GCP      Medium
#
#     Year_Founded  ... Market_Share Product_Lines  R&D_Spending  \
# ...

# %% [markdown]
# ## 17. Display companies where Ownership_Type is Public and Employees are above 5000.

# %%
df[(df['Ownership_Type'] == 'Public') & (df['Employees'] > 5000)].head()
# Out:
#     Company_ID       Company_Name             Industry Headquarters_City  \
# 3       756196    Secure Labs 605        Cybersecurity             Noida
# 8       924528     Blue Stack 604       Cloud Services           Kolkata
# 13      893599    Prime Works 368               Gaming         Ahmedabad
# 14      114360    Vertex Tech 827  Enterprise Software          Gurugram
# 20      974462  Blue Platforms 82           HealthTech          Gurugram
#
#       Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 3          UK         Public              SME           GCP         Low
# 8   Australia         Public            B2B2C           GCP        High
# 13      India         Public              B2C     IBM Cloud        High
# 14        USA         Public              SME           GCP      Medium
# 20  Australia         Public              B2C     IBM Cloud   Very High
#
#     Year_Founded  ... Market_Share Product_Lines  R&D_Spending  \
# ...

# %% [markdown]
# ## 18. Sort the dataset by Annual_Revenue in descending order.

# %%
df.sort_values('Annual_Revenue', ascending=False).head()
# Out:
#      Company_ID          Company_Name    Industry Headquarters_City  \
# 792      125280   Global Infotech 386      EdTech         Ahmedabad
# 26       871382  Quantum Services 747      EdTech           Chennai
# 719      119095     Smart Services 96      EdTech         Ahmedabad
# 750      450492     Bright Digital 50  E-commerce             Noida
# 179      181972       Bright Apps 477     FinTech           Kolkata
#
#        Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 792     Canada     Subsidiary              B2B           GCP         Low
# 26   Australia         Public              B2C     IBM Cloud      Medium
# 719      India        Private              SME           NaN   Very High
# 750     Canada         Public       Enterprise   Multi-Cloud        High
# 179         UK        Private              B2B           AWS         Low
#
#      Year_Founded  ... Market_Share Product_Lines  R&D_Spending  \
# ...

# %% [markdown]
# ## 19. Sort the dataset by Year_Founded and then Employees.

# %%
df.sort_values(['Year_Founded', 'Employees']).head()
# Out:
#      Company_ID        Company_Name    Industry Headquarters_City    Country  \
# 378      752876     Innova Labs 481  HealthTech         Bengaluru     Canada
# 383      894178  Secure Systems 633  HealthTech             Delhi    Germany
# 673      602616   Prime Digital 526       AI/ML         Ahmedabad  Singapore
# 869      256508   Tech Dynamics 593     FinTech          Gurugram  Singapore
# 755      961959    Next Digital 783       AI/ML           Kolkata        USA
#
#     Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  Year_Founded  \
# 378         Public              B2C           AWS      Medium          1985
# 383         Public            B2B2C   Multi-Cloud        High          1985
# 673         Public       Enterprise           GCP         Low          1985
# 869        Private              B2B           AWS        High          1985
# 755     Subsidiary              B2C   Multi-Cloud         Low          1985
#
# ...

# %% [markdown]
# ## 20. Create a new column Revenue_Per_Employee.

# %%
df['Revenue_Per_Employee'] = df['Annual_Revenue'] / df['Employees']
df[['Company_Name', 'Revenue_Per_Employee']].head()
# Out:
#          Company_Name  Revenue_Per_Employee
# 0        Neo Soft 760           1644.942672
# 1  Next Analytics 229          17545.554084
# 2    Innova Works 693          29803.488537
# 3     Secure Labs 605           1001.936018
# 4    Logic Systems 31          13448.030244

# %% [markdown]
# ## 21. Create a new column Company_Age using the year 2026.

# %%
df['Company_Age'] = 2026 - df['Year_Founded']
df[['Company_Name', 'Company_Age']].head()
# Out:
#          Company_Name  Company_Age
# 0        Neo Soft 760            3
# 1  Next Analytics 229           13
# 2    Innova Works 693           27
# 3     Secure Labs 605           34
# 4    Logic Systems 31           21

# %% [markdown]
# ## 22. Create a new column High_AI_Adoption that is Yes when Adoption_Rate_AI is above 70 else No.

# %%
df['High_AI_Adoption'] = np.where(df['Adoption_Rate_AI'] > 70, 'Yes', 'No')
df[['Company_Name', 'Adoption_Rate_AI', 'High_AI_Adoption']].head()
# Out:
#          Company_Name  Adoption_Rate_AI High_AI_Adoption
# 0        Neo Soft 760             27.47               No
# 1  Next Analytics 229             68.36               No
# 2    Innova Works 693             71.59              Yes
# 3     Secure Labs 605             61.48               No
# 4    Logic Systems 31             13.24               No

# %% [markdown]
# ## 23. Find the number of unique industries.

# %%
df['Industry'].nunique()
# Out:
# 10

# %% [markdown]
# ## 24. List all unique Ownership_Type values.

# %%
df['Ownership_Type'].dropna().unique().tolist()
# Out:
# ['Private', 'Startup', 'Public', 'Subsidiary']

# %% [markdown]
# ## 25. Count companies in each Industry.

# %%
df['Industry'].value_counts()
# Out:
# Industry
# SaaS                   114
# Gaming                 111
# Cybersecurity          103
# Enterprise Software    103
# HealthTech              99
# Cloud Services          97
# E-commerce              91
# AI/ML                   89
# FinTech                 89
# EdTech                  86
# Name: count, dtype: int64

# %% [markdown]
# ## 26. Count companies in each Country.

# %%
df['Country'].value_counts()
# Out:
# Country
# Canada       132
# USA          129
# Germany      128
# Australia    127
# UAE          126
# India        126
# Singapore    120
# UK           112
# Name: count, dtype: int64

# %% [markdown]
# ## 27. Find the mean number of Employees.

# %%
df['Employees'].mean()
# Out:
# np.float64(25512.567209775967)

# %% [markdown]
# ## 28. Find the median Annual_Revenue.

# %%
df['Annual_Revenue'].median()
# Out:
# np.float64(92333731.685)

# %% [markdown]
# ## 29. Find the maximum and minimum Profit_Margin.

# %%
df['Profit_Margin'].max(), df['Profit_Margin'].min()
# Out:
# (np.float64(41.98), np.float64(2.01))

# %% [markdown]
# ## 30. Find the company with the highest Annual_Revenue.

# %%
df.loc[df['Annual_Revenue'].idxmax(), ['Company_Name', 'Annual_Revenue']]
# Out:
# Company_Name      Global Infotech 386
# Annual_Revenue           1216481354.0
# Name: 792, dtype: object

# %% [markdown]
# ## 31. Find the company with the lowest Employee_Satisfaction.

# %%
df.loc[df['Employee_Satisfaction'].idxmin(), ['Company_Name', 'Employee_Satisfaction']]
# Out:
# Company_Name             Logic Apps 957
# Employee_Satisfaction               2.1
# Name: 360, dtype: object

# %% [markdown]
# ## 32. Display the top 10 companies by R&D_Spending.

# %%
df.nlargest(10, 'R&D_Spending')[['Company_Name', 'R&D_Spending']]
# Out:
#              Company_Name  R&D_Spending
# 26   Quantum Services 747  2.568302e+08
# 719     Smart Services 96  2.044561e+08
# 179       Bright Apps 477  1.781477e+08
# 382          Alpha AI 894  1.645257e+08
# 908    Blue Platforms 879  1.439280e+08
# 403    Smart Dynamics 394  1.268671e+08
# 355         Global AI 250  1.241569e+08
# 67    Cyber Platforms 409  1.164480e+08
# 245       Smart Works 816  1.122203e+08
# 837        Alpha Labs 411  1.106003e+08

# %% [markdown]
# ## 33. Display the bottom 10 companies by Market_Share.

# %%
df.nsmallest(10, 'Market_Share')[['Company_Name', 'Market_Share']]
# Out:
#              Company_Name  Market_Share
# 78          Innova AI 249          0.12
# 321       Global Stack 83          0.17
# 802    Next Platforms 125          0.21
# 981   Prime Solutions 810          0.28
# 672        Cloud Labs 688          0.29
# 653         Secure AI 260          0.30
# 889        Cyber Labs 104          0.32
# 328       Fusion Tech 186          0.33
# 428      Secure Works 466          0.38
# 776  Bright Platforms 487          0.40

# %% [markdown]
# ## 34. Find the average Annual_Revenue by Industry.

# %%
df.groupby('Industry')['Annual_Revenue'].mean().sort_values(ascending=False)
# Out:
# Industry
# EdTech                 1.432527e+08
# FinTech                1.422681e+08
# Cloud Services         1.365501e+08
# Gaming                 1.352510e+08
# E-commerce             1.285175e+08
# Cybersecurity          1.284764e+08
# HealthTech             1.214598e+08
# SaaS                   1.208081e+08
# AI/ML                  1.190923e+08
# Enterprise Software    1.175210e+08
# Name: Annual_Revenue, dtype: float64

# %% [markdown]
# ## 35. Find the average Employees by Country.

# %%
df.groupby('Country')['Employees'].mean().sort_values(ascending=False)
# Out:
# Country
# UAE          27280.572581
# Australia    26734.674603
# Germany      25602.637795
# UK           25565.787037
# India        25346.129032
# Canada       25043.267176
# USA          25025.798387
# Singapore    23411.474576
# Name: Employees, dtype: float64

# %% [markdown]
# ## 36. Find the total Annual_Revenue by Ownership_Type.

# %%
df.groupby('Ownership_Type')['Annual_Revenue'].sum().sort_values(ascending=False)
# Out:
# Ownership_Type
# Private       4.358855e+10
# Public        3.906069e+10
# Startup       2.597191e+10
# Subsidiary    1.836774e+10
# Name: Annual_Revenue, dtype: float64

# %% [markdown]
# ## 37. Find the average Profit_Margin by Customer_Segment.

# %%
df.groupby('Customer_Segment')['Profit_Margin'].mean().sort_values(ascending=False)
# Out:
# Customer_Segment
# SME           22.562011
# B2B2C         22.368205
# B2C           21.876193
# Enterprise    21.740815
# B2B           21.651306
# Name: Profit_Margin, dtype: float64

# %% [markdown]
# ## 38. Find the mean of Adoption_Rate_AI, Adoption_Rate_Cloud, and Adoption_Rate_Blockchain by Industry.

# %%
df.groupby('Industry')[['Adoption_Rate_AI', 'Adoption_Rate_Cloud', 'Adoption_Rate_Blockchain']].mean()
# Out:
#                      Adoption_Rate_AI  Adoption_Rate_Cloud  \
# Industry
# AI/ML                       57.742584            49.631236
# Cloud Services              47.355979            54.538144
# Cybersecurity               49.376214            49.617087
# E-commerce                  49.204286            55.990440
# EdTech                      52.070465            52.629535
# Enterprise Software         56.646893            52.946505
# FinTech                     47.182247            53.952022
# Gaming                      53.029189            51.856216
# HealthTech                  49.272020            56.336364
# SaaS                        49.667105            59.053509
#
#                      Adoption_Rate_Blockchain
# Industry
# AI/ML                               37.660337
# Cloud Services                      40.998351
# Cybersecurity                       35.317476
# E-commerce                          41.029670
# EdTech                              37.991279
# ...

# %% [markdown]
# ## 39. Count the number of companies by Industry and Country.

# %%
df.groupby(['Industry', 'Country']).size().sort_values(ascending=False).head(20)
# Out:
# Industry             Country
# Gaming               Singapore    22
#                      Australia    19
# Enterprise Software  Canada       17
# SaaS                 Germany      17
# HealthTech           USA          17
# Cloud Services       Germany      16
# EdTech               UAE          16
# FinTech              Singapore    16
# Gaming               Canada       16
# Enterprise Software  Australia    16
# Cybersecurity        India        16
# HealthTech           UK           16
# SaaS                 Canada       16
#                      UK           16
# Cybersecurity        UAE          16
# SaaS                 Australia    15
# Enterprise Software  USA          15
# SaaS                 India        15
#                      USA          15
# Cybersecurity        Germany      15
# dtype: int64

# %% [markdown]
# ## 40. Find the earliest Incorporation_Date.

# %%
df['Incorporation_Date'].min()
# Out:
# Timestamp('1985-01-11 00:00:00')

# %% [markdown]
# ## 41. Find the latest Last_Funding_Date.

# %%
df['Last_Funding_Date'].max()
# Out:
# Timestamp('2026-03-31 00:00:00')

# %% [markdown]
# ## 42. Extract the incorporation year into a new column Incorporation_Year.

# %%
df['Incorporation_Year'] = df['Incorporation_Date'].dt.year
df[['Company_Name', 'Incorporation_Year']].head()
# Out:
#          Company_Name  Incorporation_Year
# 0        Neo Soft 760                2023
# 1  Next Analytics 229                2013
# 2    Innova Works 693                1999
# 3     Secure Labs 605                1992
# 4    Logic Systems 31                2005

# %% [markdown]
# ## 43. Extract the funding month name into a new column Funding_Month.

# %%
df['Funding_Month'] = df['Last_Funding_Date'].dt.month_name()
df[['Company_Name', 'Funding_Month']].head()
# Out:
#          Company_Name Funding_Month
# 0        Neo Soft 760          July
# 1  Next Analytics 229      February
# 2    Innova Works 693       January
# 3     Secure Labs 605         March
# 4    Logic Systems 31           NaN

# %% [markdown]
# ## 44. Display companies incorporated in January.

# %%
df[df['Incorporation_Date'].dt.month == 1].head()
# Out:
#      Company_ID     Company_Name        Industry Headquarters_City    Country  \
# 6        146801   Pixel Soft 575  Cloud Services             Noida      India
# 45       549463    Zen Stack 542          Gaming             Delhi  Singapore
# 51       955816    Tech Tech 996            SaaS             Delhi        USA
# 82       536370  Logic Stack 885      HealthTech             Noida  Singapore
# 151      407345     Cloud AI 228          Gaming           Kolkata      India
#
#     Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  Year_Founded  \
# 6          Startup              B2C     IBM Cloud      Medium          2003
# 45         Startup            B2B2C     IBM Cloud      Medium          1991
# 51          Public            B2B2C   Multi-Cloud         Low          2024
# 82          Public            B2B2C   Multi-Cloud      Medium          1985
# 151        Private       Enterprise           GCP        High          1985
#
# ...

# %% [markdown]
# ## 45. Display companies funded in the year 2025.

# %%
df[df['Last_Funding_Date'].dt.year == 2025].head()
# Out:
#     Company_ID             Company_Name             Industry  \
# 0       807869             Neo Soft 760           HealthTech
# 5       556753        Data Dynamics 239  Enterprise Software
# 12      293852           Alpha Works 95  Enterprise Software
# 43      854652  Quantum Innovations 611               Gaming
# 44      170224            Data Corp 391                AI/ML
#
#    Headquarters_City    Country Ownership_Type Customer_Segment Primary_Cloud  \
# 0               Pune  Australia        Private              SME         Azure
# 5              Delhi  Australia        Startup            B2B2C           GCP
# 12           Chennai  Australia        Private              SME   Multi-Cloud
# 43            Mumbai      India        Startup            B2B2C   Multi-Cloud
# 44             Delhi        UAE     Subsidiary       Enterprise         Azure
#
#    Risk_Rating  Year_Founded  ... Employee_Satisfaction Adoption_Rate_AI  \
# ...

# %% [markdown]
# ## 46. Find the number of companies founded in each year.

# %%
df['Year_Founded'].value_counts().sort_index()
# Out:
# Year_Founded
# 1985    27
# 1986    28
# 1987    25
# 1988    23
# 1989    31
# 1990    26
# 1991    15
# 1992    29
# 1993    22
# 1994    21
# 1995    24
# 1996    26
# 1997    21
# 1998    24
# 1999    22
# 2000    21
# 2001    24
# 2002    18
# 2003    21
# 2004    20
# 2005    20
# 2006    24
# 2007    26
# 2008    27
# 2009    28
# 2010    37
# 2011    20
# 2012    31
# 2013    25
# 2014    24
# 2015    20
# 2016    26
# 2017    38
# 2018    19
# 2019    32
# 2020    28
# 2021    32
# 2022    21
# 2023    28
# 2024    26
# Name: count, dtype: int64

# %% [markdown]
# ## 47. Find the average Annual_Revenue for companies founded after 2010.

# %%
df.loc[df['Year_Founded'] > 2010, 'Annual_Revenue'].mean()
# Out:
# np.float64(135997992.13803324)

# %% [markdown]
# ## 48. Replace missing values in Employees with the median Employees.

# %%
df['Employees'] = df['Employees'].fillna(df['Employees'].median())
df['Employees'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 49. Replace missing values in Industry with 'Unknown'.

# %%
df['Industry'] = df['Industry'].fillna('Unknown')
df['Industry'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 50. Drop rows where Annual_Revenue is missing.

# %%
df_drop = df.dropna(subset=['Annual_Revenue'])
df_drop.shape
# Out:
# (982, 30)

# %% [markdown]
# ## 51. Fill missing Last_Funding_Date values with the most frequent date.

# %%
df['Last_Funding_Date'] = df['Last_Funding_Date'].fillna(df['Last_Funding_Date'].mode()[0])
df['Last_Funding_Date'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 52. Check whether there are duplicate Company_ID values.

# %%
df['Company_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 53. Create a duplicate-free dataset based on Company_ID.

# %%
df_no_dupes = df.drop_duplicates(subset='Company_ID')
df_no_dupes.shape
# Out:
# (1000, 30)

# %% [markdown]
# ## 54. Rename Company_Name to Organization_Name.

# %%
df.rename(columns={'Company_Name': 'Organization_Name'}).head()
# Out:
#    Company_ID   Organization_Name        Industry Headquarters_City  \
# 0      807869        Neo Soft 760      HealthTech              Pune
# 1      985270  Next Analytics 229          Gaming             Noida
# 2      615066    Innova Works 693   Cybersecurity           Chennai
# 3      756196     Secure Labs 605   Cybersecurity             Noida
# 4      292453    Logic Systems 31  Cloud Services               NaN
#
#      Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 0  Australia        Private              SME         Azure      Medium
# 1        UAE        Startup            B2B2C           GCP         Low
# 2    Germany        Startup              B2B     IBM Cloud      Medium
# 3         UK         Public              SME           GCP         Low
# 4        UAE        Private            B2B2C           AWS      Medium
#
#    Year_Founded  ... Employee_Satisfaction Adoption_Rate_AI  \
# 0          2023  ...                  3.99            27.47
# ...

# %% [markdown]
# ## 55. Convert all column names to lowercase.

# %%
df_lower = df.copy()
df_lower.columns = df_lower.columns.str.lower()
df_lower.columns.tolist()
# Out:
# ['company_id',
#  'company_name',
#  'industry',
#  'headquarters_city',
#  'country',
#  'ownership_type',
#  'customer_segment',
#  'primary_cloud',
#  'risk_rating',
#  'year_founded',
#  'incorporation_date',
#  'last_funding_date',
#  'employees',
#  'annual_revenue',
#  'profit_margin',
#  'market_share',
#  'product_lines',
#  'r&d_spending',
#  'average_salary',
#  'training_hours_per_employee',
#  'employee_satisfaction',
#  'adoption_rate_ai',
#  'adoption_rate_cloud',
#  'adoption_rate_blockchain',
#  'ceo_tenure_years',
#  'revenue_per_employee',
#  'company_age',
#  'high_ai_adoption',
#  'incorporation_year',
#  'funding_month']

# %% [markdown]
# ## 56. Add a prefix 'col_' to all column names.

# %%
df_pref = df.copy()
df_pref.columns = ['col_' + c for c in df_pref.columns]
df_pref.columns.tolist()
# Out:
# ['col_Company_ID',
#  'col_Company_Name',
#  'col_Industry',
#  'col_Headquarters_City',
#  'col_Country',
#  'col_Ownership_Type',
#  'col_Customer_Segment',
#  'col_Primary_Cloud',
#  'col_Risk_Rating',
#  'col_Year_Founded',
#  'col_Incorporation_Date',
#  'col_Last_Funding_Date',
#  'col_Employees',
#  'col_Annual_Revenue',
#  'col_Profit_Margin',
#  'col_Market_Share',
#  'col_Product_Lines',
#  'col_R&D_Spending',
#  'col_Average_Salary',
#  'col_Training_Hours_Per_Employee',
#  'col_Employee_Satisfaction',
#  'col_Adoption_Rate_AI',
#  'col_Adoption_Rate_Cloud',
#  'col_Adoption_Rate_Blockchain',
#  'col_CEO_Tenure_Years',
#  'col_Revenue_Per_Employee',
#  'col_Company_Age',
#  'col_High_AI_Adoption',
#  'col_Incorporation_Year',
#  'col_Funding_Month']

# %% [markdown]
# ## 57. Create a subset with only categorical columns.

# %%
df.select_dtypes(include='object').head()
# Out:
#          Company_Name        Industry Headquarters_City    Country  \
# 0        Neo Soft 760      HealthTech              Pune  Australia
# 1  Next Analytics 229          Gaming             Noida        UAE
# 2    Innova Works 693   Cybersecurity           Chennai    Germany
# 3     Secure Labs 605   Cybersecurity             Noida         UK
# 4    Logic Systems 31  Cloud Services               NaN        UAE
#
#   Ownership_Type Customer_Segment Primary_Cloud Risk_Rating High_AI_Adoption  \
# 0        Private              SME         Azure      Medium               No
# 1        Startup            B2B2C           GCP         Low               No
# 2        Startup              B2B     IBM Cloud      Medium              Yes
# 3         Public              SME           GCP         Low               No
# 4        Private            B2B2C           AWS      Medium               No
#
#   Funding_Month
# 0          July
# 1      February
# 2       January
# 3         March
# ...

# %% [markdown]
# ## 58. Create a subset with only numerical columns.

# %%
df.select_dtypes(include=np.number).head()
# Out:
#    Company_ID  Year_Founded  Employees  Annual_Revenue  Profit_Margin  \
# 0      807869          2023    44377.0    7.299762e+07          17.16
# 1      985270          2013     3418.0    5.997070e+07           3.39
# 2      615066          1999     3847.0    1.146540e+08           6.08
# 3      756196          1992    47932.0    4.802480e+07          26.06
# 4      292453          2005    13768.0    1.851525e+08          36.95
#
#    Market_Share  Product_Lines  R&D_Spending  Average_Salary  \
# 0         33.16             16    3959494.45      3223371.94
# 1         11.87              1    4483284.44      3440809.32
# 2         25.40             22   26299168.52      3411320.38
# 3         18.90              2    9575493.89      2329426.44
# 4          2.22              3   30870883.91      1266740.76
#
#    Training_Hours_Per_Employee  Employee_Satisfaction  Adoption_Rate_AI  \
# 0                         90.7                   3.99             27.47
# ...

# %% [markdown]
# ## 59. Find the correlation matrix of numerical columns.

# %%
df.select_dtypes(include=np.number).corr()
# Out:
#                              Company_ID  Year_Founded  Employees  \
# Company_ID                     1.000000      0.018525  -0.001080
# Year_Founded                   0.018525      1.000000  -0.033835
# Employees                     -0.001080     -0.033835   1.000000
# Annual_Revenue                -0.003653      0.054149  -0.039410
# Profit_Margin                  0.006668      0.038788  -0.012684
# Market_Share                   0.044083     -0.037843   0.039984
# Product_Lines                  0.002451     -0.010173   0.006112
# R&D_Spending                   0.004174      0.043230  -0.085839
# Average_Salary                 0.062257     -0.051673   0.003865
# Training_Hours_Per_Employee    0.053006      0.019862  -0.040651
# Employee_Satisfaction          0.026660      0.022877   0.021168
# Adoption_Rate_AI              -0.006371     -0.018082  -0.005765
# Adoption_Rate_Cloud           -0.043072     -0.033516   0.015619
# ...

# %% [markdown]
# ## 60. Find the covariance matrix of numerical columns.

# %%
df.select_dtypes(include=np.number).cov()
# Out:
#                                Company_ID  Year_Founded     Employees  \
# Company_ID                   6.736865e+10  5.664241e+04 -3.982937e+06
# Year_Founded                 5.664241e+04  1.387697e+02 -5.664325e+03
# Employees                   -3.982937e+06 -5.664325e+03  2.019655e+08
# Annual_Revenue              -1.196533e+11  8.021108e+07 -7.057511e+10
# Profit_Margin                1.986580e+04  5.240717e+00 -2.068262e+03
# Market_Share                 1.131767e+05 -4.409456e+00  5.620518e+03
# Product_Lines                4.290734e+03 -8.084094e-01  5.859574e+02
# R&D_Spending                 2.417419e+10  1.136434e+07 -2.722269e+10
# Average_Salary               1.919512e+10 -7.230851e+05  6.524462e+07
# Training_Hours_Per_Employee  4.517257e+05  7.682143e+00 -1.896861e+04
# Employee_Satisfaction        5.727246e+03  2.233144e-01  2.490469e+02
# Adoption_Rate_AI            -4.449988e+04 -5.732387e+00 -2.204979e+03
# ...

# %% [markdown]
# ## 61. Find the 25th, 50th, and 75th percentiles of Annual_Revenue.

# %%
df['Annual_Revenue'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    5.202599e+07
# 0.50    9.233373e+07
# 0.75    1.635613e+08
# Name: Annual_Revenue, dtype: float64

# %% [markdown]
# ## 62. Find companies where Employee_Satisfaction is above the dataset average.

# %%
df[df['Employee_Satisfaction'] > df['Employee_Satisfaction'].mean()].head()
# Out:
#     Company_ID             Company_Name             Industry  \
# 0       807869             Neo Soft 760           HealthTech
# 4       292453         Logic Systems 31       Cloud Services
# 5       556753        Data Dynamics 239  Enterprise Software
# 10      712043  Quantum Innovations 349  Enterprise Software
# 11      531830       Next Solutions 221               EdTech
#
#    Headquarters_City    Country Ownership_Type Customer_Segment Primary_Cloud  \
# 0               Pune  Australia        Private              SME         Azure
# 4                NaN        UAE        Private            B2B2C           AWS
# 5              Delhi  Australia        Startup            B2B2C           GCP
# 10             Delhi  Australia        Startup            B2B2C         Azure
# 11            Mumbai    Germany     Subsidiary              SME           GCP
#
#    Risk_Rating  Year_Founded  ... Employee_Satisfaction Adoption_Rate_AI  \
# ...

# %% [markdown]
# ## 63. Find companies where Annual_Revenue is between 10 million and 50 million.

# %%
df[df['Annual_Revenue'].between(10_000_000, 50_000_000)].head()
# Out:
#     Company_ID          Company_Name        Industry Headquarters_City  \
# 3       756196       Secure Labs 605   Cybersecurity             Noida
# 11      531830    Next Solutions 221          EdTech            Mumbai
# 13      893599       Prime Works 368          Gaming         Ahmedabad
# 17      420070  Secure Platforms 850  Cloud Services           Chennai
# 22      821974        Next Stack 651   Cybersecurity            Mumbai
#
#       Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 3          UK         Public              SME           GCP         Low
# 11    Germany     Subsidiary              SME           GCP         Low
# 13      India         Public              B2C     IBM Cloud        High
# 17  Singapore        Private            B2B2C         Azure        High
# 22    Germany         Public              B2C   Multi-Cloud      Medium
#
#     Year_Founded  ... Employee_Satisfaction Adoption_Rate_AI  \
# ...

# %% [markdown]
# ## 64. Find companies where Headquarters_City contains the letter 'a'.

# %%
df[df['Headquarters_City'].str.contains('a', case=False, na=False)].head()
# Out:
#    Company_ID        Company_Name        Industry Headquarters_City  Country  \
# 1      985270  Next Analytics 229          Gaming             Noida      UAE
# 2      615066    Innova Works 693   Cybersecurity           Chennai  Germany
# 3      756196     Secure Labs 605   Cybersecurity             Noida       UK
# 6      146801      Pixel Soft 575  Cloud Services             Noida    India
# 7      434129  Cyber Services 430         Unknown         Hyderabad       UK
#
#   Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  Year_Founded  \
# 1        Startup            B2B2C           GCP         Low          2013
# 2        Startup              B2B     IBM Cloud      Medium          1999
# 3         Public              SME           GCP         Low          1992
# 6        Startup              B2C     IBM Cloud      Medium          2003
# 7        Private              SME   Multi-Cloud      Medium          2007
#
# ...

# %% [markdown]
# ## 65. Convert Company_Name to uppercase in a new column Company_Name_Upper.

# %%
df['Company_Name_Upper'] = df['Company_Name'].str.upper()
df[['Company_Name', 'Company_Name_Upper']].head()
# Out:
#          Company_Name  Company_Name_Upper
# 0        Neo Soft 760        NEO SOFT 760
# 1  Next Analytics 229  NEXT ANALYTICS 229
# 2    Innova Works 693    INNOVA WORKS 693
# 3     Secure Labs 605     SECURE LABS 605
# 4    Logic Systems 31    LOGIC SYSTEMS 31

# %% [markdown]
# ## 66. Find the length of each company name in a new column Name_Length.

# %%
df['Name_Length'] = df['Company_Name'].str.len()
df[['Company_Name', 'Name_Length']].head()
# Out:
#          Company_Name  Name_Length
# 0        Neo Soft 760           12
# 1  Next Analytics 229           18
# 2    Innova Works 693           16
# 3     Secure Labs 605           15
# 4    Logic Systems 31           16

# %% [markdown]
# ## 67. Split Company_Name into two parts using the first space.

# %%
df['Name_Part1'] = df['Company_Name'].str.split().str[0]
df['Name_Part2'] = df['Company_Name'].str.split().str[1]
df[['Company_Name', 'Name_Part1', 'Name_Part2']].head()
# Out:
#          Company_Name Name_Part1 Name_Part2
# 0        Neo Soft 760        Neo       Soft
# 1  Next Analytics 229       Next  Analytics
# 2    Innova Works 693     Innova      Works
# 3     Secure Labs 605     Secure       Labs
# 4    Logic Systems 31      Logic    Systems

# %% [markdown]
# ## 68. Find the top 5 most common Headquarters_City values.

# %%
df['Headquarters_City'].value_counts().head()
# Out:
# Headquarters_City
# Chennai      117
# Pune         108
# Kolkata      108
# Hyderabad    105
# Ahmedabad    105
# Name: count, dtype: int64

# %% [markdown]
# ## 69. Create a pivot table showing average Annual_Revenue by Industry and Ownership_Type.

# %%
pd.pivot_table(df, values='Annual_Revenue', index='Industry', columns='Ownership_Type', aggfunc='mean')
# Out:
# Ownership_Type            Private        Public       Startup    Subsidiary
# Industry
# AI/ML                9.772148e+07  1.232244e+08  1.444461e+08  1.109135e+08
# Cloud Services       1.116121e+08  1.898600e+08  1.415976e+08  7.789725e+07
# Cybersecurity        1.319642e+08  1.268422e+08  1.283170e+08  1.257157e+08
# E-commerce           1.432866e+08  1.794654e+08  6.744124e+07  1.075075e+08
# EdTech               1.398922e+08  1.411313e+08  1.321157e+08  1.658297e+08
# Enterprise Software  1.095717e+08  1.517898e+08  9.577441e+07  1.111229e+08
# FinTech              1.603462e+08  1.306213e+08  1.471802e+08  1.332250e+08
# Gaming               1.206848e+08  1.413031e+08  1.535554e+08  1.422699e+08
# HealthTech           1.412163e+08  1.069900e+08  1.253207e+08  9.744974e+07
# SaaS                 1.283487e+08  9.759794e+07  1.525531e+08  9.520525e+07
# Unknown              1.485179e+08  9.642024e+07  1.851530e+08  1.900687e+08

# %% [markdown]
# ## 70. Create a pivot table showing mean Employees by Country and Customer_Segment.

# %%
pd.pivot_table(df, values='Employees', index='Country', columns='Customer_Segment', aggfunc='mean')
# Out:
# Customer_Segment           B2B         B2B2C           B2C    Enterprise  \
# Country
# Australia         31023.321429  22624.350000  26669.451613  24776.000000
# Canada            24131.264706  26975.000000  28254.000000  22533.034483
# Germany           23365.224138  27321.884615  25959.962963  23009.565217
# India             25743.258065  27643.142857  21936.777778  30056.263158
# Singapore         20500.460000  28083.642857  21130.166667  24609.555556
# UAE               25874.240741  26307.075758  28237.444444  26920.807692
# UK                24094.833333  25995.150000  24071.173077  23452.894737
# USA               27744.982143  25355.879310  22611.780000  26183.884615
#
# Customer_Segment           SME
# Country
# Australia         26824.160714
# Canada            24557.312500
# Germany           28667.652174
# India             23316.142857
# Singapore         23501.956522
# UAE               29985.409091
# UK                31717.843750
# USA               22597.428571

# %% [markdown]
# ## 71. Create a crosstab of Industry and Ownership_Type.

# %%
pd.crosstab(df['Industry'], df['Ownership_Type'])
# Out:
# Ownership_Type       Private  Public  Startup  Subsidiary
# Industry
# AI/ML                     27      24       22          16
# Cloud Services            32      27       25          13
# Cybersecurity             32      35       18          18
# E-commerce                31      23       20          17
# EdTech                    29      31       13          13
# Enterprise Software       34      28       26          15
# FinTech                   23      33       18          15
# Gaming                    47      25       23          16
# HealthTech                41      31       11          16
# SaaS                      47      27       23          17
# Unknown                    5       6        4           3

# %% [markdown]
# ## 72. Create a crosstab of Country and Risk_Rating.

# %%
pd.crosstab(df['Country'], df['Risk_Rating'])
# Out:
# Risk_Rating  High  Low  Medium  Very High
# Country
# Australia      38   23      51         15
# Canada         44   22      55         11
# Germany        33   22      61         12
# India          30   19      57         20
# Singapore      32   25      51         12
# UAE            30   16      62         18
# UK             36   17      50          9
# USA            41   21      56         11

# %% [markdown]
# ## 73. Bin Employees into 4 equal-width groups.

# %%
df['Employee_Bin'] = pd.cut(df['Employees'], bins=4)
df[['Company_Name', 'Employees', 'Employee_Bin']].head()
# Out:
#          Company_Name  Employees        Employee_Bin
# 0        Neo Soft 760    44377.0  (37512.5, 49980.0]
# 1  Next Analytics 229     3418.0    (60.13, 12577.5]
# 2    Innova Works 693     3847.0    (60.13, 12577.5]
# 3     Secure Labs 605    47932.0  (37512.5, 49980.0]
# 4    Logic Systems 31    13768.0  (12577.5, 25045.0]

# %% [markdown]
# ## 74. Bin Profit_Margin into labels Low, Medium, High.

# %%
df['Margin_Category'] = pd.cut(df['Profit_Margin'], bins=[0, 15, 30, 50], labels=['Low', 'Medium', 'High'])
df[['Company_Name', 'Profit_Margin', 'Margin_Category']].head()
# Out:
#          Company_Name  Profit_Margin Margin_Category
# 0        Neo Soft 760          17.16          Medium
# 1  Next Analytics 229           3.39             Low
# 2    Innova Works 693           6.08             Low
# 3     Secure Labs 605          26.06          Medium
# 4    Logic Systems 31          36.95            High

# %% [markdown]
# ## 75. Create a rank column based on Annual_Revenue in descending order.

# %%
df['Revenue_Rank'] = df['Annual_Revenue'].rank(ascending=False, method='dense')
df[['Company_Name', 'Annual_Revenue', 'Revenue_Rank']].head()
# Out:
#          Company_Name  Annual_Revenue  Revenue_Rank
# 0        Neo Soft 760    7.299762e+07         587.0
# 1  Next Analytics 229    5.997070e+07         676.0
# 2    Innova Works 693    1.146540e+08         392.0
# 3     Secure Labs 605    4.802480e+07         775.0
# 4    Logic Systems 31    1.851525e+08         189.0

# %% [markdown]
# ## 76. Find the top company in each Industry by Annual_Revenue.

# %%
df.loc[df.groupby('Industry')['Annual_Revenue'].idxmax(), ['Industry', 'Company_Name', 'Annual_Revenue']].sort_values('Industry')
# Out:
#                 Industry            Company_Name  Annual_Revenue
# 67                 AI/ML     Cyber Platforms 409    5.447701e+08
# 883       Cloud Services     Fusion Services 435    6.328388e+08
# 908        Cybersecurity      Blue Platforms 879    5.407233e+08
# 750           E-commerce       Bright Digital 50    7.397702e+08
# 792               EdTech     Global Infotech 386    1.216481e+09
# 298  Enterprise Software     Logic Analytics 795    5.963971e+08
# 179              FinTech         Bright Apps 477    7.375767e+08
# 516               Gaming  Fusion Innovations 280    6.887885e+08
# 986           HealthTech            Zen Corp 993    4.933153e+08
# 355                 SaaS           Global AI 250    7.351460e+08
# 457              Unknown         Innova Soft 284    3.314439e+08

# %% [markdown]
# ## 77. Find the bottom company in each Country by Profit_Margin.

# %%
df.loc[df.groupby('Country')['Profit_Margin'].idxmin(), ['Country', 'Company_Name', 'Profit_Margin']].sort_values('Country')
# Out:
#        Country          Company_Name  Profit_Margin
# 952  Australia         Global Soft 7           2.46
# 740     Canada  Fusion Analytics 145           2.48
# 207    Germany  Innova Analytics 393           2.71
# 934      India     Blue Solutions 17           2.48
# 874  Singapore    Logic Networks 788           2.01
# 699        UAE  Innova Analytics 810           2.05
# 671         UK        Logic Tech 655           2.08
# 397        USA         Next Soft 921           2.11

# %% [markdown]
# ## 78. Calculate cumulative Annual_Revenue after sorting by Year_Founded.

# %%
df_cum = df.sort_values('Year_Founded').copy()
df_cum['Cumulative_Revenue'] = df_cum['Annual_Revenue'].cumsum()
df_cum[['Company_Name', 'Year_Founded', 'Cumulative_Revenue']].head()
# Out:
#              Company_Name  Year_Founded  Cumulative_Revenue
# 218         Blue Tech 447          1985        1.925644e+08
# 661    Global Digital 947          1985        3.916965e+08
# 849     Zen Analytics 225          1985        4.408015e+08
# 658       Prime Stack 917          1985        5.408554e+08
# 439  Secure Solutions 398          1985        5.783336e+08

# %% [markdown]
# ## 79. Calculate rolling mean of Employees for a dataset sorted by Year_Founded with window 5.

# %%
df_roll = df.sort_values('Year_Founded').copy()
df_roll['Rolling_Employees_Mean'] = df_roll['Employees'].rolling(5).mean()
df_roll[['Company_Name', 'Year_Founded', 'Rolling_Employees_Mean']].head(10)
# Out:
#                Company_Name  Year_Founded  Rolling_Employees_Mean
# 218           Blue Tech 447          1985                     NaN
# 661      Global Digital 947          1985                     NaN
# 849       Zen Analytics 225          1985                     NaN
# 658         Prime Stack 917          1985                     NaN
# 439    Secure Solutions 398          1985                 37222.4
# 377  Innova Innovations 892          1985                 35117.1
# 151            Cloud AI 228          1985                 31290.7
# 378         Innova Labs 481          1985                 26785.5
# 869       Tech Dynamics 593          1985                 20184.5
# 638      Pixel Services 520          1985                 23752.9

# %% [markdown]
# ## 80. Find the percentage of companies in each Ownership_Type.

# %%
df['Ownership_Type'].value_counts(normalize=True) * 100
# Out:
# Ownership_Type
# Private       34.8
# Public        29.0
# Startup       20.3
# Subsidiary    15.9
# Name: proportion, dtype: float64

# %% [markdown]
# ## 81. Find the percentage contribution of each Industry to total Annual_Revenue.

# %%
(df.groupby('Industry')['Annual_Revenue'].sum() / df['Annual_Revenue'].sum() * 100).sort_values(ascending=False)
# Out:
# Industry
# Gaming                 11.822180
# SaaS                   10.559742
# Cloud Services         10.322803
# Cybersecurity          10.218307
# FinTech                 9.634747
# EdTech                  9.475811
# HealthTech              9.373310
# Enterprise Software     9.346972
# E-commerce              9.108337
# AI/ML                   8.065226
# Unknown                 2.072566
# Name: Annual_Revenue, dtype: float64

# %% [markdown]
# ## 82. Filter companies with AI adoption greater than cloud adoption.

# %%
df[df['Adoption_Rate_AI'] > df['Adoption_Rate_Cloud']].head()
# Out:
#     Company_ID             Company_Name             Industry  \
# 1       985270       Next Analytics 229               Gaming
# 2       615066         Innova Works 693        Cybersecurity
# 8       924528           Blue Stack 604       Cloud Services
# 10      712043  Quantum Innovations 349  Enterprise Software
# 12      293852           Alpha Works 95  Enterprise Software
#
#    Headquarters_City    Country Ownership_Type Customer_Segment Primary_Cloud  \
# 1              Noida        UAE        Startup            B2B2C           GCP
# 2            Chennai    Germany        Startup              B2B     IBM Cloud
# 8            Kolkata  Australia         Public            B2B2C           GCP
# 10             Delhi  Australia        Startup            B2B2C         Azure
# 12           Chennai  Australia        Private              SME   Multi-Cloud
#
#    Risk_Rating  Year_Founded  ... High_AI_Adoption Incorporation_Year  \
# ...

# %% [markdown]
# ## 83. Filter companies with blockchain adoption below 20 and risk rating High.

# %%
df[(df['Adoption_Rate_Blockchain'] < 20) & (df['Risk_Rating'] == 'High')].head()
# Out:
#     Company_ID         Company_Name             Industry Headquarters_City  \
# 12      293852       Alpha Works 95  Enterprise Software           Chennai
# 15      121219      Cloud Stack 550                 SaaS             Delhi
# 54      990613   Pixel Dynamics 157              FinTech         Ahmedabad
# 63      787744  Global Services 170           E-commerce          Gurugram
# 68      293974     Vertex Stack 922       Cloud Services              Pune
#
#       Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 12  Australia        Private              SME   Multi-Cloud        High
# 15  Australia        Startup              B2C           GCP        High
# 54         UK         Public              SME   Multi-Cloud        High
# 63  Singapore         Public              B2B           AWS        High
# 68  Australia        Startup              B2C           GCP        High
#
#     Year_Founded  ... High_AI_Adoption Incorporation_Year  Funding_Month  \
# ...

# %% [markdown]
# ## 84. Find companies where Average_Salary is above 20 lakh and Employee_Satisfaction is above 4.

# %%
df[(df['Average_Salary'] > 2_000_000) & (df['Employee_Satisfaction'] > 4)].head()
# Out:
#     Company_ID          Company_Name             Industry Headquarters_City  \
# 5       556753     Data Dynamics 239  Enterprise Software             Delhi
# 26      871382  Quantum Services 747               EdTech           Chennai
# 27      238014     Blue Networks 474               Gaming           Kolkata
# 28      779553        Prime Tech 948               EdTech             Noida
# 29      762223  Secure Analytics 702                 SaaS          Gurugram
#
#       Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 5   Australia        Startup            B2B2C           GCP      Medium
# 26  Australia         Public              B2C     IBM Cloud      Medium
# 27        UAE        Private              B2B           GCP        High
# 28      India        Private            B2B2C   Multi-Cloud   Very High
# 29        USA         Public              B2B           NaN         Low
#
#     Year_Founded  ... High_AI_Adoption Incorporation_Year  Funding_Month  \
# ...

# %% [markdown]
# ## 85. Create a new column Revenue_Category using qcut into 4 quantiles.

# %%
df['Revenue_Category'] = pd.qcut(df['Annual_Revenue'], q=4, labels=['Q1', 'Q2', 'Q3', 'Q4'])
df[['Company_Name', 'Annual_Revenue', 'Revenue_Category']].head()
# Out:
#          Company_Name  Annual_Revenue Revenue_Category
# 0        Neo Soft 760    7.299762e+07               Q2
# 1  Next Analytics 229    5.997070e+07               Q2
# 2    Innova Works 693    1.146540e+08               Q3
# 3     Secure Labs 605    4.802480e+07               Q1
# 4    Logic Systems 31    1.851525e+08               Q4

# %% [markdown]
# ## 86. Create a new column Funding_Year from Last_Funding_Date.

# %%
df['Funding_Year'] = df['Last_Funding_Date'].dt.year
df[['Company_Name', 'Last_Funding_Date', 'Funding_Year']].head()
# Out:
#          Company_Name Last_Funding_Date  Funding_Year
# 0        Neo Soft 760        2025-07-24          2025
# 1  Next Analytics 229        2023-02-25          2023
# 2    Innova Works 693        2004-01-08          2004
# 3     Secure Labs 605        1997-03-05          1997
# 4    Logic Systems 31        1993-06-30          1993

# %% [markdown]
# ## 87. Find the count of companies funded in each month.

# %%
df['Last_Funding_Date'].dt.month_name().value_counts()
# Out:
# Last_Funding_Date
# November     92
# March        90
# June         90
# July         88
# May          88
# January      87
# December     84
# October      82
# August       81
# September    76
# February     71
# April        71
# Name: count, dtype: int64

# %% [markdown]
# ## 88. Set Company_ID as the index.

# %%
df.set_index('Company_ID').head()
# Out:
#                   Company_Name        Industry Headquarters_City    Country  \
# Company_ID
# 807869            Neo Soft 760      HealthTech              Pune  Australia
# 985270      Next Analytics 229          Gaming             Noida        UAE
# 615066        Innova Works 693   Cybersecurity           Chennai    Germany
# 756196         Secure Labs 605   Cybersecurity             Noida         UK
# 292453        Logic Systems 31  Cloud Services               NaN        UAE
#
#            Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# Company_ID
# 807869            Private              SME         Azure      Medium
# 985270            Startup            B2B2C           GCP         Low
# 615066            Startup              B2B     IBM Cloud      Medium
# 756196             Public              SME           GCP         Low
# 292453            Private            B2B2C           AWS      Medium
#
#             Year_Founded Incorporation_Date  ... Funding_Month  \
# ...

# %% [markdown]
# ## 89. Reset the index after setting Company_ID as index.

# %%
df.set_index('Company_ID').reset_index().head()
# Out:
#    Company_ID        Company_Name        Industry Headquarters_City  \
# 0      807869        Neo Soft 760      HealthTech              Pune
# 1      985270  Next Analytics 229          Gaming             Noida
# 2      615066    Innova Works 693   Cybersecurity           Chennai
# 3      756196     Secure Labs 605   Cybersecurity             Noida
# 4      292453    Logic Systems 31  Cloud Services               NaN
#
#      Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 0  Australia        Private              SME         Azure      Medium
# 1        UAE        Startup            B2B2C           GCP         Low
# 2    Germany        Startup              B2B     IBM Cloud      Medium
# 3         UK         Public              SME           GCP         Low
# 4        UAE        Private            B2B2C           AWS      Medium
#
#    Year_Founded  ... Funding_Month  Company_Name_Upper  Name_Length  \
# ...

# %% [markdown]
# ## 90. Select rows from index position 10 to 20 and columns 2 to 6 using iloc.

# %%
df.iloc[10:21, 2:7]
# Out:
#                Industry Headquarters_City    Country Ownership_Type  \
# 10  Enterprise Software             Delhi  Australia        Startup
# 11               EdTech            Mumbai    Germany     Subsidiary
# 12  Enterprise Software           Chennai  Australia        Private
# 13               Gaming         Ahmedabad      India         Public
# 14  Enterprise Software          Gurugram        USA         Public
# 15                 SaaS             Delhi  Australia        Startup
# 16              Unknown            Mumbai      India        Startup
# 17       Cloud Services           Chennai  Singapore        Private
# 18               Gaming         Ahmedabad    Germany        Private
# 19                 SaaS         Hyderabad      India        Private
# 20           HealthTech          Gurugram  Australia         Public
#
#    Customer_Segment
# 10            B2B2C
# 11              SME
# 12              SME
# 13              B2C
# 14              SME
# 15              B2C
# ...

# %% [markdown]
# ## 91. Select Annual_Revenue and Profit_Margin for the first 10 rows using loc.

# %%
df.loc[:9, ['Annual_Revenue', 'Profit_Margin']]
# Out:
#    Annual_Revenue  Profit_Margin
# 0    7.299762e+07          17.16
# 1    5.997070e+07           3.39
# 2    1.146540e+08           6.08
# 3    4.802480e+07          26.06
# 4    1.851525e+08          36.95
# 5    8.055256e+07           6.79
# 6    6.726486e+07          20.04
# 7    1.643997e+08          38.44
# 8    6.971075e+07          34.57
# 9    1.922010e+08          22.79

# %% [markdown]
# ## 92. Find companies with the top 5 highest Employees within each Country.

# %%
df.sort_values(['Country', 'Employees'], ascending=[True, False]).groupby('Country').head(5)[['Country', 'Company_Name', 'Employees']]
# Out:
#        Country          Company_Name  Employees
# 493  Australia   Cloud Platforms 615    49519.0
# 643  Australia      Data Digital 247    48701.0
# 638  Australia    Pixel Services 520    48340.0
# 210  Australia      Secure Stack 426    47974.0
# 670  Australia     Cloud Digital 630    47887.0
# 696     Canada  Quantum Networks 813    49980.0
# 59      Canada    Smart Analytics 60    49890.0
# 581     Canada    Data Platforms 573    49888.0
# 997     Canada    Tech Platforms 456    49776.0
# 935     Canada     Next Services 958    48988.0
# 520    Germany     Smart Systems 226    49758.0
# 714    Germany      Quantum Apps 958    49203.0
# 704    Germany          Prime AI 539    48640.0
# 242    Germany        Smart Corp 407    48325.0
# 134    Germany       Innova Tech 166    47888.0
# 679      India      Innova Stack 972    49318.0
# 113      India   Prime Solutions 688    49198.0
# 278      India      Neo Dynamics 324    49132.0
# 519      India          Smart AI 540    48924.0
# ...

# %% [markdown]
# ## 93. Find the average Employee_Satisfaction for each Headquarters_City.

# %%
df.groupby('Headquarters_City')['Employee_Satisfaction'].mean().sort_values(ascending=False)
# Out:
# Headquarters_City
# Delhi        3.599211
# Gurugram     3.588913
# Pune         3.574340
# Mumbai       3.544886
# Hyderabad    3.531553
# Ahmedabad    3.531068
# Chennai      3.531034
# Bengaluru    3.495109
# Kolkata      3.472453
# Noida        3.400964
# Name: Employee_Satisfaction, dtype: float64

# %% [markdown]
# ## 94. Create a summary table with mean, median, min, and max of Annual_Revenue by Industry.

# %%
df.groupby('Industry')['Annual_Revenue'].agg(['mean', 'median', 'min', 'max'])
# Out:
#                              mean        median          min           max
# Industry
# AI/ML                1.190923e+08  1.027316e+08  12866527.13  5.447701e+08
# Cloud Services       1.365501e+08  1.065051e+08  12164935.95  6.328388e+08
# Cybersecurity        1.284764e+08  9.258418e+07   9535544.21  5.407233e+08
# E-commerce           1.285175e+08  9.339647e+07  13895177.27  7.397702e+08
# EdTech               1.432527e+08  7.666037e+07  15930389.90  1.216481e+09
# Enterprise Software  1.175210e+08  8.746194e+07   5985007.15  5.963971e+08
# FinTech              1.422681e+08  1.094834e+08  29365953.68  7.375767e+08
# Gaming               1.352510e+08  9.182475e+07  13024583.21  6.887885e+08
# HealthTech           1.214598e+08  8.104692e+07  12013770.31  4.933153e+08
# SaaS                 1.208081e+08  8.982997e+07  12492964.77  7.351460e+08
# Unknown              1.462183e+08  1.654600e+08  11955722.38  3.314439e+08

# %% [markdown]
# ## 95. Find companies whose names start with 'Tech'.

# %%
df[df['Company_Name'].str.startswith('Tech', na=False)].head()
# Out:
#      Company_ID       Company_Name        Industry Headquarters_City  Country  \
# 47       906763     Tech Works 699            SaaS          Gurugram  Germany
# 51       955816      Tech Tech 996            SaaS             Delhi      USA
# 96       157850      Tech Corp 272  Cloud Services         Hyderabad      USA
# 133      803606      Tech Apps 790      E-commerce              Pune   Canada
# 154      146298  Tech Dynamics 409      E-commerce           Chennai      UAE
#
#     Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  Year_Founded  \
# 47      Subsidiary       Enterprise           GCP      Medium          2019
# 51          Public            B2B2C   Multi-Cloud         Low          2024
# 96         Private            B2B2C         Azure      Medium          1992
# 133        Startup              B2C           AWS      Medium          2013
# 154        Startup       Enterprise         Azure   Very High          1987
#
# ...

# %% [markdown]
# ## 96. Find companies whose names end with 'AI' or 'Tech'.

# %%
df[df['Company_Name'].str.endswith(('AI', 'Tech'), na=False)].head()
# Out:
# Empty DataFrame
# Columns: [Company_ID, Company_Name, Industry, Headquarters_City, Country, Ownership_Type, Customer_Segment, Primary_Cloud, Risk_Rating, Year_Founded, Incorporation_Date, Last_Funding_Date, Employees, Annual_Revenue, Profit_Margin, Market_Share, Product_Lines, R&D_Spending, Average_Salary, Training_Hours_Per_Employee, Employee_Satisfaction, Adoption_Rate_AI, Adoption_Rate_Cloud, Adoption_Rate_Blockchain, CEO_Tenure_Years, Revenue_Per_Employee, Company_Age, High_AI_Adoption, Incorporation_Year, Funding_Month, Company_Name_Upper, Name_Length, Name_Part1, Name_Part2, Employee_Bin, Margin_Category, Revenue_Rank, Revenue_Category, Funding_Year]
# Index: []
#
# [0 rows x 39 columns]

# %% [markdown]
# ## 97. Count how many companies are in each year and industry combination.

# %%
df.groupby(['Year_Founded', 'Industry']).size().reset_index(name='Count').head(20)
# Out:
#     Year_Founded             Industry  Count
# 0           1985                AI/ML      4
# 1           1985       Cloud Services      1
# 2           1985        Cybersecurity      4
# 3           1985           E-commerce      3
# 4           1985  Enterprise Software      4
# 5           1985              FinTech      2
# 6           1985               Gaming      2
# 7           1985           HealthTech      5
# 8           1985                 SaaS      1
# 9           1985              Unknown      1
# 10          1986                AI/ML      4
# 11          1986       Cloud Services      2
# 12          1986        Cybersecurity      1
# 13          1986           E-commerce      3
# 14          1986               EdTech      3
# 15          1986  Enterprise Software      5
# 16          1986              FinTech      3
# 17          1986           HealthTech      4
# 18          1986                 SaaS      2
# 19          1986              Unknown      1

# %% [markdown]
# ## 98. Find the month-wise average Annual_Revenue based on Incorporation_Date.

# %%
df.groupby(df['Incorporation_Date'].dt.month)['Annual_Revenue'].mean()
# Out:
# Incorporation_Date
# 1     1.288762e+08
# 2     1.290164e+08
# 3     1.259628e+08
# 4     1.210445e+08
# 5     1.361203e+08
# 6     1.314044e+08
# 7     1.249001e+08
# 8     1.521258e+08
# 9     1.275576e+08
# 10    1.207644e+08
# 11    1.264686e+08
# 12    1.273874e+08
# Name: Annual_Revenue, dtype: float64

# %% [markdown]
# ## 99. Find the quarter-wise count of Last_Funding_Date.

# %%
df['Last_Funding_Date'].dt.quarter.value_counts().sort_index()
# Out:
# Last_Funding_Date
# 1    248
# 2    249
# 3    245
# 4    258
# Name: count, dtype: int64

# %% [markdown]
# ## 100. Create a boolean column Recent_Company for companies founded from 2018 onward.

# %%
df['Recent_Company'] = df['Year_Founded'] >= 2018
df[['Company_Name', 'Year_Founded', 'Recent_Company']].head()
# Out:
#          Company_Name  Year_Founded  Recent_Company
# 0        Neo Soft 760          2023            True
# 1  Next Analytics 229          2013           False
# 2    Innova Works 693          1999           False
# 3     Secure Labs 605          1992           False
# 4    Logic Systems 31          2005           False

# %% [markdown]
# ## 101. Create a boolean column Large_Workforce for companies with Employees above 20000.

# %%
df['Large_Workforce'] = df['Employees'] > 20000
df[['Company_Name', 'Employees', 'Large_Workforce']].head()
# Out:
#          Company_Name  Employees  Large_Workforce
# 0        Neo Soft 760    44377.0             True
# 1  Next Analytics 229     3418.0            False
# 2    Innova Works 693     3847.0            False
# 3     Secure Labs 605    47932.0             True
# 4    Logic Systems 31    13768.0            False

# %% [markdown]
# ## 102. Display rows where either Risk_Rating is Very High or Profit_Margin is below 10.

# %%
df[(df['Risk_Rating'] == 'Very High') | (df['Profit_Margin'] < 10)].head()
# Out:
#     Company_ID        Company_Name             Industry Headquarters_City  \
# 1       985270  Next Analytics 229               Gaming             Noida
# 2       615066    Innova Works 693        Cybersecurity           Chennai
# 5       556753   Data Dynamics 239  Enterprise Software             Delhi
# 12      293852      Alpha Works 95  Enterprise Software           Chennai
# 13      893599     Prime Works 368               Gaming         Ahmedabad
#
#       Country Ownership_Type Customer_Segment Primary_Cloud Risk_Rating  \
# 1         UAE        Startup            B2B2C           GCP         Low
# 2     Germany        Startup              B2B     IBM Cloud      Medium
# 5   Australia        Startup            B2B2C           GCP      Medium
# 12  Australia        Private              SME   Multi-Cloud        High
# 13      India         Public              B2C     IBM Cloud        High
#
#     Year_Founded  ... Name_Length Name_Part1  Name_Part2        Employee_Bin  \
# ...

# %% [markdown]
# ## 103. Find the average time gap in days between Incorporation_Date and Last_Funding_Date.

# %%
((df['Last_Funding_Date'] - df['Incorporation_Date']).dt.days).mean()
# Out:
# np.float64(3733.962)

# %% [markdown]
# ## 104. Create a new column Funding_Gap_Days for the difference between Last_Funding_Date and Incorporation_Date.

# %%
df['Funding_Gap_Days'] = (df['Last_Funding_Date'] - df['Incorporation_Date']).dt.days
df[['Company_Name', 'Funding_Gap_Days']].head()
# Out:
#          Company_Name  Funding_Gap_Days
# 0        Neo Soft 760               740
# 1  Next Analytics 229              3448
# 2    Innova Works 693              1802
# 3     Secure Labs 605              1721
# 4    Logic Systems 31             -4495

# %% [markdown]
# ## 105. Find the top 10 companies by Revenue_Per_Employee after creating the column.

# %%
df['Revenue_Per_Employee'] = df['Annual_Revenue'] / df['Employees']
df.nlargest(10, 'Revenue_Per_Employee')[['Company_Name', 'Revenue_Per_Employee']]
# Out:
#                Company_Name  Revenue_Per_Employee
# 261      Alpha Networks 500          1.229311e+06
# 908      Blue Platforms 879          8.082560e+05
# 936  Bright Innovations 303          7.762620e+05
# 729            Smart AI 251          6.347733e+05
# 251       Logic Digital 651          4.448489e+05
# 917       Prime Systems 895          3.533902e+05
# 668     Zen Innovations 171          3.063848e+05
# 67      Cyber Platforms 409          3.011443e+05
# 358        Zen Infotech 765          2.931808e+05
# 921     Alpha Platforms 980          2.524160e+05

# %% [markdown]
# ## 106. Export the cleaned dataset to a new CSV file named cleaned_software_companies.csv.

# %%
df.to_csv('cleaned_software_companies.csv', index=False)
'cleaned_software_companies.csv created'
# Out:
# 'cleaned_software_companies.csv created'

# %% [markdown]
# ## 107. Save the top 20 revenue companies to an Excel file.

# %%
df.nlargest(20, 'Annual_Revenue').to_excel('top_20_revenue_companies.xlsx', index=False)
'top_20_revenue_companies.xlsx created'
# Out:
# 'top_20_revenue_companies.xlsx created'

# %% [markdown]
# ## 108. Read only Company_Name and Annual_Revenue columns from the CSV file.

# %%
pd.read_csv('software_companies_dataset_v2.csv', usecols=['Company_Name', 'Annual_Revenue']).head()
# Out:
#          Company_Name  Annual_Revenue
# 0        Neo Soft 760    7.299762e+07
# 1  Next Analytics 229    5.997070e+07
# 2    Innova Works 693    1.146540e+08
# 3     Secure Labs 605    4.802480e+07
# 4    Logic Systems 31    1.851525e+08

# %% [markdown]
# ## 109. Find memory usage of each column.

# %%
df.memory_usage(deep=True)
# Out:
# Index                            132
# Company_ID                      8000
# Company_Name                   65445
# Industry                       58386
# Headquarters_City              55538
# Country                        54530
# Ownership_Type                 56187
# Customer_Segment               53727
# Primary_Cloud                  54608
# Risk_Rating                    54261
# Year_Founded                    8000
# Incorporation_Date              8000
# Last_Funding_Date               8000
# Employees                       8000
# Annual_Revenue                  8000
# Profit_Margin                   8000
# Market_Share                    8000
# Product_Lines                   8000
# R&D_Spending                    8000
# Average_Salary                  8000
# Training_Hours_Per_Employee     8000
# Employee_Satisfaction           8000
# Adoption_Rate_AI                8000
# Adoption_Rate_Cloud             8000
# Adoption_Rate_Blockchain        8000
# ...

# %% [markdown]
# ## 110. Display the first 3 rows transposed.

# %%
df.head(3).T
# Out:
#                                                0                    1  \
# Company_ID                                807869               985270
# Company_Name                        Neo Soft 760   Next Analytics 229
# Industry                              HealthTech               Gaming
# Headquarters_City                           Pune                Noida
# Country                                Australia                  UAE
# Ownership_Type                           Private              Startup
# Customer_Segment                             SME                B2B2C
# Primary_Cloud                              Azure                  GCP
# Risk_Rating                               Medium                  Low
# Year_Founded                                2023                 2013
# Incorporation_Date           2023-07-15 00:00:00  2013-09-17 00:00:00
# Last_Funding_Date            2025-07-24 00:00:00  2023-02-25 00:00:00
# ...

# %% [markdown]
# ## 111. Generate a compact overall summary using info().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Company_ID                   1000 non-null   int64
#  1   Company_Name                 1000 non-null   object
#  2   Industry                     1000 non-null   object
#  3   Headquarters_City            982 non-null    object
#  4   Country                      1000 non-null   object
#  5   Ownership_Type               1000 non-null   object
#  6   Customer_Segment             1000 non-null   object
#  7   Primary_Cloud                982 non-null    object
#  8   Risk_Rating                  1000 non-null   object
#  9   Year_Founded                 1000 non-null   int64
#  10  Incorporation_Date           1000 non-null   datetime64[ns]
#  11  Last_Funding_Date            1000 non-null   datetime64[ns]
# ...

# %% [markdown]
# ## 112. Create a line plot showing the average Annual_Revenue by Year_Founded.

# %%
import matplotlib.pyplot as plt
avg_rev_by_year = df.groupby('Year_Founded')['Annual_Revenue'].mean()
plt.figure(figsize=(10, 5))
avg_rev_by_year.plot()
plt.title('Average Annual Revenue by Year Founded')
plt.xlabel('Year Founded')
plt.ylabel('Average Annual Revenue')
plt.show()

# %% [markdown]
# ## 113. Create a bar chart of the number of companies in each Industry.

# %%
import matplotlib.pyplot as plt
industry_counts = df['Industry'].value_counts()
plt.figure(figsize=(10, 5))
industry_counts.plot(kind='bar')
plt.title('Company Count by Industry')
plt.xlabel('Industry')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 114. Create a horizontal bar chart of the top 10 countries by average Employees.

# %%
import matplotlib.pyplot as plt
country_emp = df.groupby('Country')['Employees'].mean().sort_values().tail(10)
plt.figure(figsize=(10, 5))
country_emp.plot(kind='barh')
plt.title('Average Employees by Country')
plt.xlabel('Average Employees')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## 115. Create a histogram of Annual_Revenue.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.hist(df['Annual_Revenue'].dropna(), bins=30)
plt.title('Distribution of Annual Revenue')
plt.xlabel('Annual Revenue')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 116. Create a histogram of Profit_Margin using seaborn.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
sns.histplot(df['Profit_Margin'].dropna(), bins=20, kde=True)
plt.title('Distribution of Profit Margin')
plt.show()

# %% [markdown]
# ## 117. Create a box plot of Employees by Ownership_Type.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Ownership_Type', y='Employees')
plt.title('Employees by Ownership Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 118. Create a scatter plot between Annual_Revenue and R&D_Spending.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.scatter(df['Annual_Revenue'], df['R&D_Spending'])
plt.title('Annual Revenue vs R&D Spending')
plt.xlabel('Annual Revenue')
plt.ylabel('R&D Spending')
plt.show()

# %% [markdown]
# ## 119. Create a scatter plot between Adoption_Rate_AI and Employee_Satisfaction using seaborn.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x='Adoption_Rate_AI', y='Employee_Satisfaction', hue='Ownership_Type')
plt.title('AI Adoption vs Employee Satisfaction')
plt.show()

# %% [markdown]
# ## 120. Create a count plot of Risk_Rating.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Risk_Rating')
plt.title('Count of Risk Ratings')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 121. Create a pie chart of Customer_Segment distribution.

# %%
import matplotlib.pyplot as plt
segment_counts = df['Customer_Segment'].value_counts()
plt.figure(figsize=(7, 7))
plt.pie(segment_counts, labels=segment_counts.index, autopct='%1.1f%%')
plt.title('Customer Segment Distribution')
plt.show()

# %% [markdown]
# ## 122. Create a heatmap of correlations among numerical columns.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = df.select_dtypes(include='number').corr()
plt.figure(figsize=(14, 10))
sns.heatmap(corr, annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## 123. Create a violin plot of Profit_Margin by Industry.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))
sns.violinplot(data=df, x='Industry', y='Profit_Margin')
plt.title('Profit Margin by Industry')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 124. Create a stacked bar chart of Ownership_Type counts by Country.

# %%
import matplotlib.pyplot as plt
stacked_data = pd.crosstab(df['Country'], df['Ownership_Type'])
stacked_data.plot(kind='bar', stacked=True, figsize=(10, 5))
plt.title('Ownership Type by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 125. Create a seaborn pairplot for Employees, Annual_Revenue, Profit_Margin, and Employee_Satisfaction.

# %%
import seaborn as sns
sns.pairplot(df[['Employees', 'Annual_Revenue', 'Profit_Margin', 'Employee_Satisfaction']].dropna())

# %% [markdown]
# ## 126. Create a monthly line chart of company counts based on Incorporation_Date month.

# %%
import matplotlib.pyplot as plt
monthly_counts = df['Incorporation_Date'].dt.month.value_counts().sort_index()
plt.figure(figsize=(10, 5))
plt.plot(monthly_counts.index, monthly_counts.values, marker='o')
plt.title('Monthly Company Count by Incorporation Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()
